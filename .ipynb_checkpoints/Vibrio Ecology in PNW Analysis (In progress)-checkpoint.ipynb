# %% [markdown]
# This dataset was taken from NOAA at https://www.fisheries.noaa.gov/inport/item/17958.
# The purpose of the study was to invetigate how envirnmental factors affect vibrio populations in the pacific northwest due to the increase in cases of vibrio-related gastroenteritis ue to consumption of raw oysters. TDH+ stands for '
# Thermostable direct hemolysin (TDH), a major virulence factor of Vibrio parahaemolyticus'. This toxin beomes deactivated at around 60 to 70C, but becomes reactivated if the temperature crosses 80C. The purpose of this analysis is to investigate how NOAA collected data can explain the increase in TDH positive and overall vibrio populations in the PNW area.

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
import seaborn as sns

# %%
#Load dataset
df = pd.read_csv('/Users/danielaquijano/Documents/GitHub/Python-ML/source_files/Vibrio ecology in PNW - Vibrio Parahaemolyticus Survey Washington 2007-2008 Data.csv')
df.head()
# Out:
#    Sample #       Date Collected        Sampling Time     Time Of Low Tide  \
# 0       442  2008-07-01 00:00:00  2008-07-01 11:00:00  2008-07-01 09:50:00
# 1       438  2008-07-01 00:00:00  2008-07-01 09:00:00  2008-07-01 07:00:00
# 2       439  2008-07-01 00:00:00  2008-07-01 12:00:00  2008-07-01 10:50:00
# 3       443  2008-07-02 00:00:00  2008-07-02 09:50:00  2008-07-02 10:52:00
# 4       445  2008-07-02 00:00:00  2008-07-02 12:30:00  2008-07-02 12:00:00
#
#    Julian Day Site Code         Site Name  Site Latitude  Site Longitude  \
# 0         182   JCMI005       Mystery Bay       48.05690      -122.69488
# 1         182   PAWB002          Nahcotta       46.45461      -124.00977
# 2         182   TCSS0E0         Eld Inlet       47.11399      -122.94886
# 3         183   KPHC012      Misery point       47.65506      -122.82842
# 4         183   MCHI018  Hammersley Inlet       47.20665      -123.01017
#
#    Air Temperature  ...  Total Vibrio Parahaemolyticus, Water  \
# 0             18.7  ...                                4220.0
# 1             14.8  ...                                6950.0
# 2             18.2  ...                               17400.0
# 3             22.2  ...                               14000.0
# 4             24.7  ...                                   NaN
#
#    Tdh+ Vibrio Parahaemolyticus, Water  \
# 0                               2060.0
# 1                                  0.0
# 2                               9660.0
# 3                               5470.0
# 4                                  NaN
#
#    Total Vibrio Parahaemolyticus, Net Tow  \
# 0                                 11100.0
# 1                                  1780.0
# 2                                    15.1
# 3                                     NaN
# 4                                 62900.0
#
#    Tdh+ Vibrio Parahaemolyticus, Net Tow  \
# 0                                5110.00
# 1                                 868.00
# 2                                   2.98
# 3                                    NaN
# 4                               23500.00
#
#    Total Vibrio Parahemolyticus, Oyster  Tdh+ Vibrio Parahaemolyticus, Oyster  \
# 0                                   0.0                                 0.000
# 1                                   9.3                                 0.000
# 2                                  75.0                                 0.036
# 3                                   NaN                                   NaN
# 4                                   2.3                                 0.000
#
#    Record Number                    Accessed Date  \
# 0   Row 1 of 702  Accessed on 2022-02-15 20:47:36
# 1   Row 2 of 702  Accessed on 2022-02-15 20:47:36
# 2   Row 3 of 702  Accessed on 2022-02-15 20:47:36
# 3   Row 4 of 702  Accessed on 2022-02-15 20:47:36
# 4   Row 5 of 702  Accessed on 2022-02-15 20:47:36
#
#                                           Source Url  \
# 0  https://www.webapps.nwfsc.noaa.gov/apex/parrda...
# 1  https://www.webapps.nwfsc.noaa.gov/apex/parrda...
# 2  https://www.webapps.nwfsc.noaa.gov/apex/parrda...
# 3  https://www.webapps.nwfsc.noaa.gov/apex/parrda...
# 4  https://www.webapps.nwfsc.noaa.gov/apex/parrda...
#
#                                   Preferred Citation
# 0  Paranjpye, Rohinee; 02/23/2017. NOAA Fisheries...
# 1  Paranjpye, Rohinee; 02/23/2017. NOAA Fisheries...
# 2  Paranjpye, Rohinee; 02/23/2017. NOAA Fisheries...
# 3  Paranjpye, Rohinee; 02/23/2017. NOAA Fisheries...
# 4  Paranjpye, Rohinee; 02/23/2017. NOAA Fisheries...
#
# [5 rows x 25 columns]

# %%
df.isna().sum() #Check number of missing values in each column
# Out:
# Sample #                                    0
# Date Collected                              0
# Sampling Time                               0
# Time Of Low Tide                            0
# Julian Day                                  0
# Site Code                                   0
# Site Name                                   0
# Site Latitude                               0
# Site Longitude                              0
# Air Temperature                            18
# Surface Water Temperature                  10
# Water Temperature At -3 Feet               17
# Salinity                                   19
# Chlorophyll                                 7
# Oyster Tissue Temperature                  74
# Total Vibrio Parahaemolyticus, Water       56
# Tdh+ Vibrio Parahaemolyticus, Water        57
# Total Vibrio Parahaemolyticus, Net Tow     63
# Tdh+ Vibrio Parahaemolyticus, Net Tow      63
# Total Vibrio Parahemolyticus, Oyster      124
# Tdh+ Vibrio Parahaemolyticus, Oyster      125
# Record Number                               0
# Accessed Date                               0
# Source Url                                  0
# Preferred Citation                          0
# dtype: int64

# %%
df=df.dropna() #Drop any row with empty values.

# %%
sns.pairplot(df, vars=['Tdh+ Vibrio Parahaemolyticus, Water','Tdh+ Vibrio Parahaemolyticus, Net Tow','Tdh+ Vibrio Parahaemolyticus, Oyster','Surface Water Temperature','Water Temperature At -3 Feet','Salinity','Chlorophyll'])

# %% [markdown]
# These plots above show:
#     -Linear relationship between surface water temperature and temperature at -3 feet
#     -Normal-like distribution of  water temperature vs chlorophyll, vibrio counts and water temperature (temperatures around 15C showed highest vibrio populations)
#     -A right skewed distribution of salinity vs chlorophyll (higher salinity, higher chlorophyll)
#     -A right skewed distribution showing higher tdh vibrio at higher salinity
#     -A left skewed distribution showing lower chlorophyll values associated with higher vibrio populations

# %%
df

# %% [markdown]
# Make map of counts of samples from each place

# %%
Map_Bounds = [df['Site Longitude'].min(), df['Site Longitude'].max(),df['Site Latitude'].min(),df['Site Latitude'].max() ]
Map_Bounds
# Out:
# [-124.03573999999999, -122.48548000000001, 46.454609999999995, 48.58865]

# %%
# Obtain map with coordinates above from  opestreetmap.org
#imread() method loads an image from the specified file. 
mymap = plt.imread('/Users/danielaquijano/Documents/GitHub/Python-ML/source_files/map.png')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df['Site Longitude'],df['Site Latitude'], zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Plotting Spatial Data from samples collected in PNW')
ax.set_xlim(Map_Bounds[0],Map_Bounds[1])
ax.set_ylim(Map_Bounds[2],Map_Bounds[3])
ax.imshow(mymap, zorder=0, extent = Map_Bounds, aspect= 'equal')

# %% [markdown]
# I want to predict the amount of TDH+ based off of:
# Salinity
# Chlorophyll
# Oyster Tissue Temperature
# Air Temperature
# Surface Water Temperature
# Water Temperature At -3 Feet
# sklearn's regression random forest will be used for this prediction

# %%
#Define target variable & features
features=['Salinity','Chlorophyll','Oyster Tissue Temperature','Air Temperature','Surface Water Temperature','Water Temperature At -3 Feet']
features_df=pd.DataFrame()
for name in features:
    features_df[name]=df[name]

# %%
features_df
# Out:
#      Salinity  Chlorophyll  Oyster Tissue Temperature  Air Temperature  \
# 0        28.0        8.839                       21.1             18.7
# 1        24.0        5.438                       14.0             14.8
# 2        21.0        5.066                       26.4             18.2
# 5        27.0        2.732                       23.8             21.0
# 6        25.0        1.532                       23.6             24.0
# ..        ...          ...                        ...              ...
# 697      28.0        2.036                       21.8             18.6
# 698      28.0        4.734                       26.0             20.1
# 699      24.0        2.512                       13.9             14.0
# 700      18.0        0.788                       23.6             15.7
# 701       6.0        0.547                       18.0             17.2
#
#      Surface Water Temperature  Water Temperature At -3 Feet
# 0                         19.2                          19.0
# 1                         17.8                          17.8
# 2                         21.2                          21.4
# 5                         20.9                          20.0
# 6                         17.8                          17.8
# ..                         ...                           ...
# 697                       19.1                          18.0
# 698                       18.7                          18.0
# 699                       17.0                          16.9
# 700                       19.2                          19.2
# 701                       17.9                          20.1
#
# [442 rows x 6 columns]

# %%
X=features_df
y=df['Tdh+ Vibrio Parahaemolyticus, Water']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.ensemble import RandomForestRegressor
model_RF_regression=RandomForestRegressor(n_estimators=5)
model_RF_regression.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=5)

# %%
y_predictions=model_RF_regression.predict(X_test)

# %%
y_predictions
# Out:
# array([5.1878000e+02, 3.4706000e+03, 3.2644040e+04, 4.2488000e+03,
#        1.8960000e+03, 1.9066200e+03, 2.0774000e+03, 2.2124232e+04,
#        1.9895720e+04, 1.0121600e+02, 5.9600000e+03, 2.9800000e+03,
#        7.1472000e+01, 6.3682000e+04, 1.3214400e+03, 1.1293260e+03,
#        4.5042000e+02, 6.6600000e+01, 7.4104000e+03, 2.2323940e+04,
#        8.5222000e+01, 3.2337760e+03, 0.0000000e+00, 1.6104000e+03,
#        2.1394000e+05, 6.7162000e+02, 1.7166000e+03, 5.9582000e+03,
#        4.9286000e+03, 1.4890000e+02, 4.3000000e+02, 0.0000000e+00,
#        1.8960000e+03, 1.4638422e+04, 1.8157000e+03, 9.8601000e+02,
#        3.0292000e+03, 8.0532600e+02, 9.8920000e+03, 3.3420000e+01,
#        7.4969200e+03, 1.1582000e+03, 2.2374000e+03, 2.5400000e+02,
#        3.2533440e+04, 6.1128000e+04, 2.5720000e+03, 6.0446280e+04,
#        4.0641400e+02, 2.2800000e+00, 2.0263800e+03, 1.4697600e+03,
#        1.6178200e+03, 8.9000000e+01, 6.1896040e+04, 5.9600000e+03,
#        1.9214000e+04, 1.5504000e+01, 2.1908000e+05, 7.4770000e+03,
#        2.0367800e+03, 1.1432000e+03, 1.5535240e+04, 5.2013260e+03,
#        2.0232000e+03, 4.9200000e+01, 5.3000000e+01, 2.7711400e+02,
#        1.7012000e+01, 1.2886000e+03, 8.1542000e+02, 5.6154000e+03,
#        1.6780000e+01, 0.0000000e+00, 1.1980000e+01, 7.4142000e+02,
#        1.2170000e+03, 7.2200000e+01, 7.7932600e+02, 1.5658000e+04,
#        5.7000000e+00, 1.6856000e+03, 5.8983800e+02, 3.8039892e+04,
#        5.4420000e+02, 1.3400000e+02, 3.5120000e+02, 2.9200000e+01,
#        3.0400220e+03, 1.9807600e+03, 1.9180000e+02, 1.4696320e+04,
#        1.5176000e+01, 5.9200000e+02, 1.1636000e+03, 6.0400000e+01,
#        9.3604000e+03, 5.1862000e+01, 2.9476600e+03, 2.1840000e+02,
#        5.8600000e+01, 3.2422000e+01, 7.5860000e+02, 3.3038000e+03,
#        3.0992000e+02, 3.2320000e+04, 5.4082000e+03, 5.2000000e+01,
#        1.5086000e+02, 3.7985620e+03, 2.2096000e+02, 1.5464000e+01,
#        1.0550200e+03, 8.4840000e+01, 1.8984040e+03, 2.0917120e+05,
#        3.8429760e+03, 2.7370000e+02, 4.3836000e+01, 4.5226000e+02,
#        1.1402940e+04, 9.9930000e+01, 3.2470220e+04, 1.0972560e+05,
#        1.5463400e+03, 8.0020000e+01, 5.6564000e+03, 3.5660000e+01,
#        2.5720000e+02, 7.8264000e+03, 3.3520000e+03, 2.8038000e+03,
#        9.3204000e+03])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predictions)
# Out:
# -0.2435487686955402
